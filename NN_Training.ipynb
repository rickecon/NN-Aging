# %% [markdown]
# # Neural Net Estimation Code for Surrogate Model for Sensitivity Analysis for Macroeconomics of Aging
# To run this notebook, use the `dynviz-dev` virtual conda environment, which can be built using the `environment.yml` file located in the same directory as this notebook (`conda env create -f environment.yml`).
#
# This notebook builds a surrogate model for a sensitivity analysis tool for the macroeconomic impacts of improvements in biological aging. In this project, each simulation of a reform scenario of the OG-USA macroeconomic model takes about 30 minutes on a fairly powerful machine. From our simulations, we wanted to test the sensitivity of the results to six variables. If we wanted to look at all the permutations of the model for three values in each of the six input variables, that would equal 729 runs of the model.
#
# If we assume that the equilibrium solutions are continuous and smooth between those points, we could fit a surrogate model function to those six input variables and an output variable (a regression model).
#
# The following $X$ and $y$ data represent $N=27,472$ observations from a linear interpolant of 472 simulations of our model, each with different values of the $X$ input variables. These original 472 simulations represent all the permutations of the max and min values of the 6 input variables in $X$ ($N\times 6$ matrix) plus some remaining interior point observations. (The last 472 observations are the original 472 observations.)
#
# The final caveat is that we need our final interpolant to be a tensorflow neural net because that is the only model that the `tensorflow.js` library can host on a web page.
#
# **THE PROBLEM WE ARE STUCK ON (TRYING TO SOLVE)**
#
# We assumed that a deep net would fit the data well and provide a smooth interpolant of our training data and test data. However, as can be seen below, our neural net does not fit the training data very well. We wanted to know if you have any insights into how to fit a neural net to these data better.

# %%
# imports
import numpy as np
import os
import pandas as pd
import scipy.interpolate as si
import pickle
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import tensorflow_decision_forests as tfdf
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## 1. Prep the data
# The following data contains 1 predicted variable $y$ which is an $N\times 1$ vector and one matrix of 6 input variables $X$ which is an $N\times 6$ matrix, where $N=27,472$.

# %%
# Set the current directory as the cur_dir path
cur_dir = os.getcwd()
data_dir = os.path.join(cur_dir, 'data')

# Read in the data
X = np.loadtxt(os.path.join(data_dir, 'X.txt'), delimiter=',')
y = np.loadtxt(os.path.join(data_dir, 'y.txt'), delimiter=',').reshape(-1, 1)
print(f"The shape of X is {X.shape}")
print(f"The shape of y is {y.shape}")
# Out:
# The shape of X is (27472, 6)
# The shape of y is (27472, 1)

# %%
# Normalize the data
X_min = X.min(axis=0).reshape(1, -1)
X_max = X.max(axis=0).reshape(1, -1)
y_min = y.min()
y_max = y.max()

X_norm = (X - X_min) / (X_max - X_min)
y_norm = (y - y_min) / (y_max - y_min)

# %%
# train-test split for model evaluation
X_norm_train, X_norm_test, y_norm_train, y_norm_test = train_test_split(
    X_norm, y_norm, train_size=0.8, shuffle=True
)

# %%
def normalize(data, min, max):
    data_norm = (data - min) / (max - min)
    return data_norm

def denormalize(data_norm, min, max):
    data = data_norm * (max - min) + min
    return data

# %% [markdown]
# Here is the linear N-dimensional interpolant that we fit to our sparse runs of 472 data points in this $(X,y)$ space. This interpolant `interpolant_avg_diff()` is an estimated `scipy.interpolate.LinearNDInterpolator` object. This would be useful, e.g., if you want to use the surrogate model to generate new data points for each epoch.

# %%
interpolant_avg_diff = pickle.load(
    open(
        os.path.join(data_dir, "interpolant_avg_diff.pkl"), "rb"
    )
)
# using
prediction = interpolant_avg_diff(denormalize(X_norm_test, X_min, X_max))
print("Predictions = ", prediction[:5])
# Out:
# /var/folders/d4/trj3dssd6s3g8kxvjmczz11w0000gn/T/ipykernel_47862/2950532527.py:1: DeprecationWarning: Please import `LinearNDInterpolator` from the `scipy.interpolate` namespace; the `scipy.interpolate.interpnd` namespace is deprecated and will be removed in SciPy 2.0.0.
#   interpolant_avg_diff = pickle.load(
# Predictions =  [[ 984.48842979]
#  [ 931.2680149 ]
#  [ 955.49679256]
#  [1311.44194172]
#  [2458.0718794 ]]

# %% [markdown]
# ## 2. Set up the NN model

# %%
# set some hyperparameters
nodes_per_layer = 20 # multiplied by num inputs
activation_function = "relu"
num_epochs = 100
learning_rate = 0.001
# set up early stopping
callback = keras.callbacks.EarlyStopping(monitor='loss', patience=5000)

# %%
# Layer setting
num_input = X.shape[1]
num_hidden_layers = 7
num_hidden = np.zeros(num_hidden_layers)
# Start with more nodes per layer and decrease
for i in range(num_hidden_layers):
    num_hidden[i] = (nodes_per_layer - i * 2) * num_input
# num_hidden = nodes_per_layer * num_input
num_output = y.shape[1]
layers_dim = [num_input, num_hidden, num_output]
print("Dimensions of each layer are {}".format(layers_dim))
# Out:
# Dimensions of each layer are [6, array([120., 108.,  96.,  84.,  72.,  60.,  48.]), 1]

# %%
# Define the normalization function of the output
def normalize_output(data):
    data_max = np.max(data)
    data_min = np.min(data)
    return (data - data_min) / (data_max - data_min)

# %%
# # Create a normalization layer for the inputs
# norm_layer = tf.keras.layers.Normalization(input_shape=[num_input,], axis=-1)
# norm_layer = tf.keras.layers.Normalization(input_shape=[num_input,], axis=None)

# Initialize the weights
initializer = tf.keras.initializers.HeNormal(99)
# initializer = tf.keras.initializers.HeUniform()

# Adapt the layer to your training data
# norm_layer.adapt(X_train)
nn = tf.keras.Sequential(
    [
        keras.layers.Dense(num_hidden[0], activation=activation_function, kernel_initializer=initializer),
        keras.layers.Dense(num_hidden[1], activation=activation_function, kernel_initializer=initializer),
        keras.layers.Dense(num_hidden[2], activation=activation_function, kernel_initializer=initializer),
        keras.layers.Dense(num_hidden[3], activation=activation_function, kernel_initializer=initializer),
        keras.layers.Dense(num_hidden[4], activation=activation_function, kernel_initializer=initializer),
        keras.layers.Dense(num_hidden[5], activation=activation_function, kernel_initializer=initializer),
        keras.layers.Dense(num_hidden[6], activation=activation_function, kernel_initializer=initializer),
        keras.layers.Dense(num_output, kernel_initializer=initializer),
    ]
)
# print(nn.summary())

# %%
loss_fn = tf.keras.losses.MeanSquaredError()
optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=learning_rate)
nn.compile(optimizer=optimizer, loss=loss_fn, metrics=['mean_squared_error'])

# %% [markdown]
# ## 3. Train the NN model

# %%
history = nn.fit(
    X_norm_train, y_norm_train,
    epochs=num_epochs,
    callbacks=[callback],
    # sample_weight=sample_weights,
    batch_size=32,
    validation_data=(X_norm_test,  y_norm_test),
    validation_freq=5,   # Evaluate every 5 epochs
    verbose=1
)
# Out:
# Epoch 1/100
# 687/687 [==============================] - 1s 1ms/step - loss: 0.0014 - mean_squared_error: 0.0014
# Epoch 2/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.0314e-04 - mean_squared_error: 3.0314e-04
# Epoch 3/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.0272e-04 - mean_squared_error: 2.0272e-04
# Epoch 4/100
# 687/687 [==============================] - 1s 1ms/step - loss: 1.6538e-04 - mean_squared_error: 1.6538e-04
# Epoch 5/100
# 687/687 [==============================] - 1s 1ms/step - loss: 1.4241e-04 - mean_squared_error: 1.4241e-04 - val_loss: 1.1060e-04 - val_mean_squared_error: 1.1060e-04
# Epoch 6/100
# 687/687 [==============================] - 1s 1ms/step - loss: 1.2734e-04 - mean_squared_error: 1.2734e-04
# Epoch 7/100
# 687/687 [==============================] - 1s 1ms/step - loss: 1.5117e-04 - mean_squared_error: 1.5117e-04
# Epoch 8/100
# 687/687 [==============================] - 1s 1ms/step - loss: 1.1247e-04 - mean_squared_error: 1.1247e-04
# Epoch 9/100
# 687/687 [==============================] - 1s 1ms/step - loss: 1.4612e-04 - mean_squared_error: 1.4612e-04
# Epoch 10/100
# 687/687 [==============================] - 1s 1ms/step - loss: 1.2324e-04 - mean_squared_error: 1.2324e-04 - val_loss: 3.7711e-04 - val_mean_squared_error: 3.7711e-04
# Epoch 11/100
# 687/687 [==============================] - 1s 1ms/step - loss: 1.0759e-04 - mean_squared_error: 1.0759e-04
# Epoch 12/100
# 687/687 [==============================] - 1s 1ms/step - loss: 1.2236e-04 - mean_squared_error: 1.2236e-04
# Epoch 13/100
# 687/687 [==============================] - 1s 1ms/step - loss: 1.1257e-04 - mean_squared_error: 1.1257e-04
# Epoch 14/100
# 687/687 [==============================] - 1s 1ms/step - loss: 8.3781e-05 - mean_squared_error: 8.3781e-05
# Epoch 15/100
# 687/687 [==============================] - 1s 1ms/step - loss: 7.8722e-05 - mean_squared_error: 7.8722e-05 - val_loss: 1.1669e-04 - val_mean_squared_error: 1.1669e-04
# Epoch 16/100
# 687/687 [==============================] - 1s 1ms/step - loss: 8.5027e-05 - mean_squared_error: 8.5027e-05
# Epoch 17/100
# 687/687 [==============================] - 1s 1ms/step - loss: 7.5477e-05 - mean_squared_error: 7.5477e-05
# Epoch 18/100
# 687/687 [==============================] - 1s 1ms/step - loss: 8.6861e-05 - mean_squared_error: 8.6861e-05
# Epoch 19/100
# 687/687 [==============================] - 1s 1ms/step - loss: 8.1186e-05 - mean_squared_error: 8.1186e-05
# Epoch 20/100
# 687/687 [==============================] - 1s 1ms/step - loss: 7.7822e-05 - mean_squared_error: 7.7822e-05 - val_loss: 7.5002e-05 - val_mean_squared_error: 7.5002e-05
# Epoch 21/100
# 687/687 [==============================] - 1s 1ms/step - loss: 6.2872e-05 - mean_squared_error: 6.2872e-05
# Epoch 22/100
# 687/687 [==============================] - 1s 1ms/step - loss: 6.6943e-05 - mean_squared_error: 6.6943e-05
# Epoch 23/100
# 687/687 [==============================] - 1s 1ms/step - loss: 8.6210e-05 - mean_squared_error: 8.6210e-05
# Epoch 24/100
# 687/687 [==============================] - 1s 1ms/step - loss: 6.3866e-05 - mean_squared_error: 6.3866e-05
# Epoch 25/100
# 687/687 [==============================] - 1s 1ms/step - loss: 6.5121e-05 - mean_squared_error: 6.5121e-05 - val_loss: 5.0745e-05 - val_mean_squared_error: 5.0745e-05
# Epoch 26/100
# 687/687 [==============================] - 1s 1ms/step - loss: 7.3295e-05 - mean_squared_error: 7.3295e-05
# Epoch 27/100
# 687/687 [==============================] - 1s 1ms/step - loss: 5.9696e-05 - mean_squared_error: 5.9696e-05
# Epoch 28/100
# 687/687 [==============================] - 1s 1ms/step - loss: 5.6072e-05 - mean_squared_error: 5.6072e-05
# Epoch 29/100
# 687/687 [==============================] - 1s 1ms/step - loss: 5.4880e-05 - mean_squared_error: 5.4880e-05
# Epoch 30/100
# 687/687 [==============================] - 1s 1ms/step - loss: 5.4325e-05 - mean_squared_error: 5.4325e-05 - val_loss: 4.9696e-05 - val_mean_squared_error: 4.9696e-05
# Epoch 31/100
# 687/687 [==============================] - 1s 1ms/step - loss: 5.5757e-05 - mean_squared_error: 5.5757e-05
# Epoch 32/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.8273e-05 - mean_squared_error: 4.8273e-05
# Epoch 33/100
# 687/687 [==============================] - 1s 1ms/step - loss: 5.1985e-05 - mean_squared_error: 5.1985e-05
# Epoch 34/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.9111e-05 - mean_squared_error: 4.9111e-05
# Epoch 35/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.9531e-05 - mean_squared_error: 4.9531e-05 - val_loss: 4.3950e-05 - val_mean_squared_error: 4.3950e-05
# Epoch 36/100
# 687/687 [==============================] - 1s 1ms/step - loss: 5.3013e-05 - mean_squared_error: 5.3013e-05
# Epoch 37/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.5935e-05 - mean_squared_error: 4.5935e-05
# Epoch 38/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.5118e-05 - mean_squared_error: 4.5118e-05
# Epoch 39/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.4810e-05 - mean_squared_error: 4.4810e-05
# Epoch 40/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.7066e-05 - mean_squared_error: 4.7066e-05 - val_loss: 7.0364e-05 - val_mean_squared_error: 7.0364e-05
# Epoch 41/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.2617e-05 - mean_squared_error: 4.2617e-05
# Epoch 42/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.4320e-05 - mean_squared_error: 4.4320e-05
# Epoch 43/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.1149e-05 - mean_squared_error: 4.1149e-05
# Epoch 44/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.8623e-05 - mean_squared_error: 3.8623e-05
# Epoch 45/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.1778e-05 - mean_squared_error: 4.1778e-05 - val_loss: 4.4571e-05 - val_mean_squared_error: 4.4571e-05
# Epoch 46/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.1094e-05 - mean_squared_error: 4.1094e-05
# Epoch 47/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.0095e-05 - mean_squared_error: 4.0095e-05
# Epoch 48/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.7046e-05 - mean_squared_error: 3.7046e-05
# Epoch 49/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.8082e-05 - mean_squared_error: 3.8082e-05
# Epoch 50/100
# 687/687 [==============================] - 1s 1ms/step - loss: 4.3900e-05 - mean_squared_error: 4.3900e-05 - val_loss: 3.7871e-05 - val_mean_squared_error: 3.7871e-05
# Epoch 51/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.4706e-05 - mean_squared_error: 3.4706e-05
# Epoch 52/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.5854e-05 - mean_squared_error: 3.5854e-05
# Epoch 53/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.7322e-05 - mean_squared_error: 3.7322e-05
# Epoch 54/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.6317e-05 - mean_squared_error: 3.6317e-05
# Epoch 55/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.4667e-05 - mean_squared_error: 3.4667e-05 - val_loss: 4.4714e-05 - val_mean_squared_error: 4.4714e-05
# Epoch 56/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.4953e-05 - mean_squared_error: 3.4953e-05
# Epoch 57/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.3853e-05 - mean_squared_error: 3.3853e-05
# Epoch 58/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.9032e-05 - mean_squared_error: 3.9032e-05
# Epoch 59/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.3987e-05 - mean_squared_error: 3.3987e-05
# Epoch 60/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.3854e-05 - mean_squared_error: 3.3854e-05 - val_loss: 4.1492e-05 - val_mean_squared_error: 4.1492e-05
# Epoch 61/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.3722e-05 - mean_squared_error: 3.3722e-05
# Epoch 62/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.9518e-05 - mean_squared_error: 2.9518e-05
# Epoch 63/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.2451e-05 - mean_squared_error: 3.2451e-05
# Epoch 64/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.4496e-05 - mean_squared_error: 3.4496e-05
# Epoch 65/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.1927e-05 - mean_squared_error: 3.1927e-05 - val_loss: 4.3746e-05 - val_mean_squared_error: 4.3746e-05
# Epoch 66/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.1799e-05 - mean_squared_error: 3.1799e-05
# Epoch 67/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.1453e-05 - mean_squared_error: 3.1453e-05
# Epoch 68/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.1840e-05 - mean_squared_error: 3.1840e-05
# Epoch 69/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.9775e-05 - mean_squared_error: 3.9775e-05
# Epoch 70/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.8346e-05 - mean_squared_error: 2.8346e-05 - val_loss: 3.2469e-05 - val_mean_squared_error: 3.2469e-05
# Epoch 71/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.0782e-05 - mean_squared_error: 3.0782e-05
# Epoch 72/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.8445e-05 - mean_squared_error: 2.8445e-05
# Epoch 73/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.9350e-05 - mean_squared_error: 2.9350e-05
# Epoch 74/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.9801e-05 - mean_squared_error: 2.9801e-05
# Epoch 75/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.8769e-05 - mean_squared_error: 2.8769e-05 - val_loss: 3.0470e-05 - val_mean_squared_error: 3.0470e-05
# Epoch 76/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.9009e-05 - mean_squared_error: 2.9009e-05
# Epoch 77/100
# 687/687 [==============================] - 1s 1ms/step - loss: 3.0547e-05 - mean_squared_error: 3.0547e-05
# Epoch 78/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.9470e-05 - mean_squared_error: 2.9470e-05
# Epoch 79/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.8107e-05 - mean_squared_error: 2.8107e-05
# Epoch 80/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.8239e-05 - mean_squared_error: 2.8239e-05 - val_loss: 3.0352e-05 - val_mean_squared_error: 3.0352e-05
# Epoch 81/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.5514e-05 - mean_squared_error: 2.5514e-05
# Epoch 82/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.7863e-05 - mean_squared_error: 2.7863e-05
# Epoch 83/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.4735e-05 - mean_squared_error: 2.4735e-05
# Epoch 84/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.6534e-05 - mean_squared_error: 2.6534e-05
# Epoch 85/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.7881e-05 - mean_squared_error: 2.7881e-05 - val_loss: 3.0323e-05 - val_mean_squared_error: 3.0323e-05
# Epoch 86/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.7450e-05 - mean_squared_error: 2.7450e-05
# Epoch 87/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.7099e-05 - mean_squared_error: 2.7099e-05
# Epoch 88/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.7156e-05 - mean_squared_error: 2.7156e-05
# Epoch 89/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.6210e-05 - mean_squared_error: 2.6210e-05
# Epoch 90/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.6886e-05 - mean_squared_error: 2.6886e-05 - val_loss: 3.7848e-05 - val_mean_squared_error: 3.7848e-05
# Epoch 91/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.6923e-05 - mean_squared_error: 2.6923e-05
# Epoch 92/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.7079e-05 - mean_squared_error: 2.7079e-05
# Epoch 93/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.3847e-05 - mean_squared_error: 2.3847e-05
# Epoch 94/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.8496e-05 - mean_squared_error: 2.8496e-05
# Epoch 95/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.4451e-05 - mean_squared_error: 2.4451e-05 - val_loss: 2.9376e-05 - val_mean_squared_error: 2.9376e-05
# Epoch 96/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.4208e-05 - mean_squared_error: 2.4208e-05
# Epoch 97/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.5125e-05 - mean_squared_error: 2.5125e-05
# Epoch 98/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.4056e-05 - mean_squared_error: 2.4056e-05
# Epoch 99/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.4775e-05 - mean_squared_error: 2.4775e-05
# Epoch 100/100
# 687/687 [==============================] - 1s 1ms/step - loss: 2.6184e-05 - mean_squared_error: 2.6184e-05 - val_loss: 2.8096e-05 - val_mean_squared_error: 2.8096e-05

# %%
# Plot training and validation loss
plt.plot(np.arange(num_epochs), history.history['loss'], label='Train Loss')
plt.plot(
    np.linspace(0, num_epochs, num=int(np.ceil(num_epochs/5))),
    history.history['val_loss'], label='Test Loss', marker='o'
)
plt.ylim(0, 0.0005)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Train vs Test Loss')
plt.legend()
plt.show()

# %% [markdown]
# ## 4. Check the fit of the model

# %%
nn.evaluate(X_norm,  y_norm, verbose=2)
# Out:
# 859/859 - 0s - loss: 1.9653e-05 - mean_squared_error: 1.9653e-05 - 313ms/epoch - 364us/step
# [1.9653100025607273e-05, 1.9653100025607273e-05]

# %% [markdown]
# ### 4.1. Checking against the original data

# %%
output_variable = "avg_diff"
predictions_normed = nn.predict(X_norm)
# Rescale the predictions
predictions = predictions_normed * (y_max - y_min) + y_min
y_pred = predictions
y_diff = y - y_pred
print(
    f"The mean abs diff between y and y_pred is {np.absolute(y_diff).mean()}."
)
print(f"The max diff between y and y_pred is {y_diff.max()}.")
print(f"The min diff between y and y_pred is {y_diff.min()}.")
# Out:
# 859/859 [==============================] - 0s 386us/step
# The mean abs diff between y and y_pred is 15.183420879170114.
# The max diff between y and y_pred is 163.56958266516085.
# The min diff between y and y_pred is -227.1540967074634.

# %%
normalization_layer = nn.get_layer('normalization')
mean = normalization_layer.mean.numpy()
variance = normalization_layer.variance.numpy()
print("Mean: ", mean)
print("Std dev: ", variance**(1/2))
# Out:
# Mean:  [[54.73748     8.35946     8.381766    1.8990896   1.8962128   0.53320134]]
# Std dev:  [[5.95917    4.787876   4.805051   1.4172095  1.4169149  0.39561728]]

# %% [markdown]
# ### 4.2. Check closeness to runs used in Silver Linings Book
#
# There are a number of runs included in the Silver Linings book that we want to hit **extremely** closely. These happen to be the last 472 observations of the $X$ and $y$ data objects. We can check how close the surrogate model is to these runs.

# %%
# Load model
X_book = X[-472:, :]
y_book = y[-472:, :]

# predict using the model
y_book_pred_norm = nn.predict(X_book)
y_book_pred = y_book_pred_norm * (y.max() - y.min()) + y.min()
y_book_diff = y_book - y_book_pred
print(
    f"The mean abs diff between y_book_pred and y_book " +
    f"is {np.absolute(y_book_diff).mean()}."
)
print(f"The max diff between y_book_pred and y_book is {y_book_diff.max()}.")
print(f"The min diff between y_book_pred and y_book is {y_book_diff.min()}.")
# Out:
# 15/15 [==============================] - 0s 512us/step
# The mean abs diff between y_book_pred and y_book is 39.115684254982874.
# The max diff between y_book_pred and y_book is 38.33527331989353.
# The min diff between y_book_pred and y_book is -130.4563545554597.
